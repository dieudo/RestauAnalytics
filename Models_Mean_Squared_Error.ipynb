# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt
#import geopandas as gpd
warnings.filterwarnings('ignore')
% pylab inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
metrics=pd.read_csv("Metrics.csv")

# %%
metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
# Model                            5 non-null object
# AvgScoreSquare                   5 non-null float64
# Mean Squared Error Percentage    5 non-null float64
# Mean Squared Error               5 non-null float64
# Square Root of Error             5 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 280.0+ bytes

# %%
metrics.plot.bar(x='Model', y='Mean Squared Error Percentage')

# %%
plt.show()

# %% [markdown]
# ### TAKING THE SQUARE ROOT OF THE MSE

# %%
metrics.plot.bar(x='Model', y='Square Root of Error')
